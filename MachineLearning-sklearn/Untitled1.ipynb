# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://movie.douban.com/')
res.encoding = 'utf-8'
soup = BeautifulSoup(res.text,'lxml')
#print(soup.text)
#print(soup.select('.title'))

   

a = soup.select('.title')
b = a[:10]
c = soup.select('.rating')[:10]
d = []
e = []

for move_name in b:
    str1 = move_name.text
    #print(str1)
    e.append([str1])

print(e)



for move_rate in c:
    str2 = move_rate.text
    print(str2)
    d.append([str2])
        
print(d)




#下面是保存成csv文档的方式（将一个二重列表[[],[]]写入到csv文件中）
import csv  
def createListCSV():
    fileName='D:\\python CrawlerSaveFile\\1.csv' 
    dataList =d
    with open(fileName, "w") as csvFile:
        csvWriter = csv.writer(csvFile)
        for data in dataList:
            csvWriter.writerow(data)
        csvFile.close
        
g = createListCSV()



import csv  
def createListCSV():
    fileName='D:\\python CrawlerSaveFile\\2.csv' 
    dataList =e
    with open(fileName, "w") as csvFile:
        csvWriter = csv.writer(csvFile)
        for data in dataList:
            csvWriter.writerow(data)
        csvFile.close
        
g = createListCSV()



a = []

for i in soup.select('.ui-slide-item '):
    a.append(i)

a = a[:10]
for j in a:
    print(j['data-actors'])
# Out:
# [['\n复仇者联盟3...\n'], ['\n后来的我们\n'], ['\n我是你妈\n'], ['\n幕后玩家\n'], ['\n战犬瑞克斯\n'], ['\n小公主艾薇拉...\n'], ['\n亲爱的，我要...\n'], ['\n巴霍巴利王2...\n'], ['\n狂暴巨兽\n'], ['\n七号公馆\n']]
#
# 8.5
#
#
# 5.8
#
#
# 5.0
#
#
# 6.0
#
#
# 6.9
#
#
# 3.5
#
#
# 暂无评分
#
#
# 7.0
#
#
# 6.7
#
#
# 暂无评分
#
# [['\n8.5\n'], ['\n5.8\n'], ['\n5.0\n'], ['\n6.0\n'], ['\n6.9\n'], ['\n3.5\n'], ['\n暂无评分\n'], ['\n7.0\n'], ['\n6.7\n'], ['\n暂无评分\n']]
# 小罗伯特·唐尼 / 克里斯·海姆斯沃斯 / 克里斯·埃文斯
# 井柏然 / 周冬雨 / 田壮壮
# 闫妮 / 邹元清 / 吴若甫
# 徐峥 / 王丽坤 / 王砚辉
# 凯特·玛拉 / 汤姆·费尔顿 / 布莱德利·惠特福德
#
# 保剑锋 / 戚砚笛 / 徐一娢
# 帕拉巴斯 / 拉纳·达格巴提 / 安努舒卡·谢蒂
# 道恩·强森 / 娜奥米·哈里斯 / 杰弗里·迪恩·摩根
# 梁小龙 / 张继聪 / 林雪
